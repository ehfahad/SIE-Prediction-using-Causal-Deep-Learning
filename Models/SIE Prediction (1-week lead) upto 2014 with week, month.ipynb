# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("H:\My Drive\iHARP\SIE Prediction\Arctic_domain_mean_1979_2018 - Curated.csv")

df['sea_ice_extent'] = df['sea_ice_extent']/10**6

# Some irregular values from 1/2/1988 to 1/12/1988

# %%
df['Day'] = pd.to_datetime(df['Day'], infer_datetime_format=True)
df.set_index('Day', inplace=True)
df = df.astype(float)

# %%
#df['day']  = df.index.day
df['week'] = df.index.week
df['month']  = df.index.month
#df['year'] = df.index.year

cols = ['week','month']
df = df[cols + [c for c in df.columns if c not in cols]]
# Out:
# C:\Users\FAHAD\AppData\Local\Temp/ipykernel_35268/3070580184.py:2: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   df['week'] = df.index.week

# %%
df.tail(len(df))
# Out:
#             week  month  wind_10m  specific_humidity     LW_down   SW_down  \
# Day
# 1979-01-01     1      1  5.872050           0.786595  184.999071  1.417925
# 1979-01-02     1      1  6.155597           0.756973  182.686318  1.368594
# 1979-01-03     1      1  5.691054           0.777598  186.387764  1.197913
# 1979-01-04     1      1  5.628824           0.819629  191.888081  1.405106
# 1979-01-05     1      1  6.255928           0.869896  190.541890  1.305893
# ...          ...    ...       ...                ...         ...       ...
# 2018-12-27    52     12  5.700206           1.026874  195.631612  1.005868
# 2018-12-28    52     12  5.960630           0.992543  195.926366  1.127954
# 2018-12-29    52     12  5.778559           0.940292  197.973447  1.219972
# 2018-12-30    52     12  5.740958           0.915177  198.412025  1.032733
# 2018-12-31     1     12  6.117746           1.005677  201.779379  1.046342
#
#             rainfall  snowfall   sosaline         sst         t2m  \
# Day
# 1979-01-01  1.089897  1.031549  33.341556  273.379711  250.401819
# 1979-01-02  0.923499  0.837877  33.341556  273.376830  250.364683
# 1979-01-03  1.218984  1.066028  33.341556  273.385489  250.452749
# 1979-01-04  1.783778  1.448627  33.341556  273.396461  250.290579
# 1979-01-05  0.995828  0.776768  33.341556  273.404602  250.895886
# ...              ...       ...        ...         ...         ...
# 2018-12-27  1.047516  0.807935  33.437008  273.993458  253.176978
# 2018-12-28  1.188444  0.906977  33.437008  274.009713  252.957151
# 2018-12-29  1.276387  1.065541  33.437008  273.986577  253.040940
# 2018-12-30  1.615151  1.145141  33.437008  273.976200  253.828257
# 2018-12-31  1.714896  1.362761  33.437008  273.969103  254.370636
#
#             surface_pressure  sea_ice_extent
# Day
# 1979-01-01        979.401142       14.585189
# 1979-01-02        979.340886       14.997215
# 1979-01-03        983.409060       14.997215
# 1979-01-04        983.557055       14.922219
# 1979-01-05        978.020927       14.922219
# ...                      ...             ...
# 2018-12-27        983.214961       12.324834
# 2018-12-28        983.126983       12.343956
# 2018-12-29        981.042709       12.523124
# 2018-12-30        978.119315       12.569464
# 2018-12-31        975.886335       12.621146
#
# [14610 rows x 13 columns]

# %%
def create_model_data (dataset, look_back, lead_time):
    dataX, dataY = [], []
    
    for i in range(len(dataset)-look_back-lead_time):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back + lead_time])
    return np.array(dataX), np.array(dataY)

# %%
target_index = df.columns.tolist().index('sea_ice_extent')

dataset = df.values.astype('float32') # DataFrame converted to Numpy Array

scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

X, y = create_model_data (dataset, look_back=30, lead_time=7)        # 30 days lead time
y = y[:,target_index]

# %%
#train_size = int(len(X) * 0.80)

intance_2014 = 12784 - 30 - 7

trainX = X[:intance_2014]
trainY = y[:intance_2014]
testX = X[intance_2014:]
testY = y[intance_2014:]

# %%
train_size = int(len(X) * 0.8)

plt.figure(figsize = (16,6), facecolor = '#dcdcdc')
ax = plt.axes()
ax.set_facecolor('#dcdcdc')

plt.title('Arctic Sea Ice Extent Trend from 1979-2018', fontsize = 20,fontweight = "bold")
plt.xlabel('Time' , fontsize = 18,fontweight = "bold")
plt.ylabel('Sea Ice Extent (10\u2076 km\u00b2)', fontsize = 18,fontweight = "bold")
plt.plot(df['sea_ice_extent'][:len(df)-len(testY)], 'blue', label='Training Data')
plt.plot(df['sea_ice_extent'][len(df)-len(testY):], 'red', label='Testing Data')
plt.legend()
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, LSTM, GRU, Dense

model = Sequential()
model.add(GRU(30, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(64 ,  activation = 'softmax'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mae', 'mse'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30, 30)            4050
#
#  dropout (Dropout)           (None, 30, 30)            0
#
#  lstm (LSTM)                 (None, 256)               293888
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 314,451
# Trainable params: 314,451
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='min')

callbacks_list = [checkpoint]
history = model.fit(trainX, trainY, epochs=100, batch_size=64, verbose=1, callbacks=callbacks_list, validation_split=0.1)
# Out:
# Epoch 1/100
# 180/180 [==============================] - ETA: 0s - loss: 0.1141 - mae: 0.2842 - mse: 0.1141WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 22s 96ms/step - loss: 0.1141 - mae: 0.2842 - mse: 0.1141 - val_loss: 0.0758 - val_mae: 0.2416 - val_mse: 0.0758
# Epoch 2/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0567 - mae: 0.2092 - mse: 0.0567WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 17s 97ms/step - loss: 0.0567 - mae: 0.2092 - mse: 0.0567 - val_loss: 0.0856 - val_mae: 0.2448 - val_mse: 0.0856
# Epoch 3/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0551 - mae: 0.2041 - mse: 0.0551WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 102ms/step - loss: 0.0551 - mae: 0.2041 - mse: 0.0551 - val_loss: 0.0877 - val_mae: 0.2458 - val_mse: 0.0877
# Epoch 4/100
# 179/180 [============================>.] - ETA: 0s - loss: 0.0551 - mae: 0.2037 - mse: 0.0551WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 19s 107ms/step - loss: 0.0551 - mae: 0.2037 - mse: 0.0551 - val_loss: 0.0882 - val_mae: 0.2461 - val_mse: 0.0882
# Epoch 5/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0551 - mae: 0.2036 - mse: 0.0551WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 20s 110ms/step - loss: 0.0551 - mae: 0.2036 - mse: 0.0551 - val_loss: 0.0869 - val_mae: 0.2454 - val_mse: 0.0869
# Epoch 6/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0229 - mae: 0.1183 - mse: 0.0229WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 21s 114ms/step - loss: 0.0229 - mae: 0.1183 - mse: 0.0229 - val_loss: 0.0090 - val_mae: 0.0672 - val_mse: 0.0090
# Epoch 7/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0036 - mae: 0.0475 - mse: 0.0036WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 24s 135ms/step - loss: 0.0036 - mae: 0.0475 - mse: 0.0036 - val_loss: 0.0053 - val_mae: 0.0505 - val_mse: 0.0053
# Epoch 8/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0018 - mae: 0.0335 - mse: 0.0018WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 0.0018 - mae: 0.0335 - mse: 0.0018 - val_loss: 0.0043 - val_mae: 0.0502 - val_mse: 0.0043
# Epoch 9/100
# 180/180 [==============================] - ETA: 0s - loss: 0.0012 - mae: 0.0269 - mse: 0.0012WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 27s 148ms/step - loss: 0.0012 - mae: 0.0269 - mse: 0.0012 - val_loss: 0.0025 - val_mae: 0.0324 - val_mse: 0.0025
# Epoch 10/100
# 180/180 [==============================] - ETA: 0s - loss: 9.8992e-04 - mae: 0.0244 - mse: 9.8992e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 146ms/step - loss: 9.8992e-04 - mae: 0.0244 - mse: 9.8992e-04 - val_loss: 0.0024 - val_mae: 0.0331 - val_mse: 0.0024
# Epoch 11/100
# 180/180 [==============================] - ETA: 0s - loss: 8.9302e-04 - mae: 0.0232 - mse: 8.9302e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 144ms/step - loss: 8.9302e-04 - mae: 0.0232 - mse: 8.9302e-04 - val_loss: 0.0019 - val_mae: 0.0281 - val_mse: 0.0019
# Epoch 12/100
# 180/180 [==============================] - ETA: 0s - loss: 7.5291e-04 - mae: 0.0213 - mse: 7.5291e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 146ms/step - loss: 7.5291e-04 - mae: 0.0213 - mse: 7.5291e-04 - val_loss: 0.0016 - val_mae: 0.0285 - val_mse: 0.0016
# Epoch 13/100
# 180/180 [==============================] - ETA: 0s - loss: 7.1076e-04 - mae: 0.0208 - mse: 7.1076e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 146ms/step - loss: 7.1076e-04 - mae: 0.0208 - mse: 7.1076e-04 - val_loss: 0.0014 - val_mae: 0.0248 - val_mse: 0.0014
# Epoch 14/100
# 180/180 [==============================] - ETA: 0s - loss: 6.7361e-04 - mae: 0.0203 - mse: 6.7361e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 143ms/step - loss: 6.7361e-04 - mae: 0.0203 - mse: 6.7361e-04 - val_loss: 0.0015 - val_mae: 0.0293 - val_mse: 0.0015
# Epoch 15/100
# 180/180 [==============================] - ETA: 0s - loss: 6.3496e-04 - mae: 0.0197 - mse: 6.3496e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 142ms/step - loss: 6.3496e-04 - mae: 0.0197 - mse: 6.3496e-04 - val_loss: 0.0012 - val_mae: 0.0229 - val_mse: 0.0012
# Epoch 16/100
# 180/180 [==============================] - ETA: 0s - loss: 6.0636e-04 - mae: 0.0192 - mse: 6.0636e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 142ms/step - loss: 6.0636e-04 - mae: 0.0192 - mse: 6.0636e-04 - val_loss: 0.0010 - val_mae: 0.0217 - val_mse: 0.0010
# Epoch 17/100
# 180/180 [==============================] - ETA: 0s - loss: 5.5040e-04 - mae: 0.0184 - mse: 5.5040e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 5.5040e-04 - mae: 0.0184 - mse: 5.5040e-04 - val_loss: 9.3136e-04 - val_mae: 0.0208 - val_mse: 9.3136e-04
# Epoch 18/100
# 180/180 [==============================] - ETA: 0s - loss: 5.4970e-04 - mae: 0.0185 - mse: 5.4970e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 136ms/step - loss: 5.4970e-04 - mae: 0.0185 - mse: 5.4970e-04 - val_loss: 0.0013 - val_mae: 0.0270 - val_mse: 0.0013
# Epoch 19/100
# 180/180 [==============================] - ETA: 0s - loss: 5.6295e-04 - mae: 0.0187 - mse: 5.6295e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 137ms/step - loss: 5.6295e-04 - mae: 0.0187 - mse: 5.6295e-04 - val_loss: 0.0013 - val_mae: 0.0264 - val_mse: 0.0013
# Epoch 20/100
# 180/180 [==============================] - ETA: 0s - loss: 5.2528e-04 - mae: 0.0180 - mse: 5.2528e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 5.2528e-04 - mae: 0.0180 - mse: 5.2528e-04 - val_loss: 0.0011 - val_mae: 0.0244 - val_mse: 0.0011
# Epoch 21/100
# 180/180 [==============================] - ETA: 0s - loss: 5.3996e-04 - mae: 0.0184 - mse: 5.3996e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 5.3996e-04 - mae: 0.0184 - mse: 5.3996e-04 - val_loss: 8.3394e-04 - val_mae: 0.0208 - val_mse: 8.3394e-04
# Epoch 22/100
# 180/180 [==============================] - ETA: 0s - loss: 5.0866e-04 - mae: 0.0178 - mse: 5.0866e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 24s 136ms/step - loss: 5.0866e-04 - mae: 0.0178 - mse: 5.0866e-04 - val_loss: 8.2750e-04 - val_mae: 0.0209 - val_mse: 8.2750e-04
# Epoch 23/100
# 180/180 [==============================] - ETA: 0s - loss: 4.7511e-04 - mae: 0.0172 - mse: 4.7511e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 137ms/step - loss: 4.7511e-04 - mae: 0.0172 - mse: 4.7511e-04 - val_loss: 7.0514e-04 - val_mae: 0.0178 - val_mse: 7.0514e-04
# Epoch 24/100
# 180/180 [==============================] - ETA: 0s - loss: 4.6370e-04 - mae: 0.0169 - mse: 4.6370e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 4.6370e-04 - mae: 0.0169 - mse: 4.6370e-04 - val_loss: 6.6677e-04 - val_mae: 0.0176 - val_mse: 6.6677e-04
# Epoch 25/100
# 180/180 [==============================] - ETA: 0s - loss: 4.4288e-04 - mae: 0.0166 - mse: 4.4288e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 4.4288e-04 - mae: 0.0166 - mse: 4.4288e-04 - val_loss: 7.0824e-04 - val_mae: 0.0189 - val_mse: 7.0824e-04
# Epoch 26/100
# 180/180 [==============================] - ETA: 0s - loss: 4.5076e-04 - mae: 0.0168 - mse: 4.5076e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 4.5076e-04 - mae: 0.0168 - mse: 4.5076e-04 - val_loss: 7.2179e-04 - val_mae: 0.0186 - val_mse: 7.2179e-04
# Epoch 27/100
# 180/180 [==============================] - ETA: 0s - loss: 4.3380e-04 - mae: 0.0165 - mse: 4.3380e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 4.3380e-04 - mae: 0.0165 - mse: 4.3380e-04 - val_loss: 7.5732e-04 - val_mae: 0.0205 - val_mse: 7.5732e-04
# Epoch 28/100
# 180/180 [==============================] - ETA: 0s - loss: 4.2298e-04 - mae: 0.0162 - mse: 4.2298e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 4.2298e-04 - mae: 0.0162 - mse: 4.2298e-04 - val_loss: 7.6506e-04 - val_mae: 0.0207 - val_mse: 7.6506e-04
# Epoch 29/100
# 180/180 [==============================] - ETA: 0s - loss: 4.3623e-04 - mae: 0.0165 - mse: 4.3623e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 4.3623e-04 - mae: 0.0165 - mse: 4.3623e-04 - val_loss: 5.7432e-04 - val_mae: 0.0166 - val_mse: 5.7432e-04
# Epoch 30/100
# 180/180 [==============================] - ETA: 0s - loss: 4.1588e-04 - mae: 0.0161 - mse: 4.1588e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 4.1588e-04 - mae: 0.0161 - mse: 4.1588e-04 - val_loss: 6.7019e-04 - val_mae: 0.0187 - val_mse: 6.7019e-04
# Epoch 31/100
# 180/180 [==============================] - ETA: 0s - loss: 4.2344e-04 - mae: 0.0162 - mse: 4.2344e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 4.2344e-04 - mae: 0.0162 - mse: 4.2344e-04 - val_loss: 7.7990e-04 - val_mae: 0.0212 - val_mse: 7.7990e-04
# Epoch 32/100
# 180/180 [==============================] - ETA: 0s - loss: 4.0193e-04 - mae: 0.0157 - mse: 4.0193e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 136ms/step - loss: 4.0193e-04 - mae: 0.0157 - mse: 4.0193e-04 - val_loss: 5.8264e-04 - val_mae: 0.0174 - val_mse: 5.8264e-04
# Epoch 33/100
# 180/180 [==============================] - ETA: 0s - loss: 4.0500e-04 - mae: 0.0158 - mse: 4.0500e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 4.0500e-04 - mae: 0.0158 - mse: 4.0500e-04 - val_loss: 6.8530e-04 - val_mae: 0.0190 - val_mse: 6.8530e-04
# Epoch 34/100
# 180/180 [==============================] - ETA: 0s - loss: 3.7152e-04 - mae: 0.0152 - mse: 3.7152e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 3.7152e-04 - mae: 0.0152 - mse: 3.7152e-04 - val_loss: 6.4257e-04 - val_mae: 0.0178 - val_mse: 6.4257e-04
# Epoch 35/100
# 180/180 [==============================] - ETA: 0s - loss: 3.8489e-04 - mae: 0.0155 - mse: 3.8489e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 3.8489e-04 - mae: 0.0155 - mse: 3.8489e-04 - val_loss: 5.8924e-04 - val_mae: 0.0176 - val_mse: 5.8924e-04
# Epoch 36/100
# 180/180 [==============================] - ETA: 0s - loss: 3.6339e-04 - mae: 0.0150 - mse: 3.6339e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 3.6339e-04 - mae: 0.0150 - mse: 3.6339e-04 - val_loss: 4.6347e-04 - val_mae: 0.0151 - val_mse: 4.6347e-04
# Epoch 37/100
# 180/180 [==============================] - ETA: 0s - loss: 4.0107e-04 - mae: 0.0158 - mse: 4.0107e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 4.0107e-04 - mae: 0.0158 - mse: 4.0107e-04 - val_loss: 4.8063e-04 - val_mae: 0.0152 - val_mse: 4.8063e-04
# Epoch 38/100
# 180/180 [==============================] - ETA: 0s - loss: 3.9693e-04 - mae: 0.0157 - mse: 3.9693e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 142ms/step - loss: 3.9693e-04 - mae: 0.0157 - mse: 3.9693e-04 - val_loss: 6.2023e-04 - val_mae: 0.0180 - val_mse: 6.2023e-04
# Epoch 39/100
# 180/180 [==============================] - ETA: 0s - loss: 3.5118e-04 - mae: 0.0147 - mse: 3.5118e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 3.5118e-04 - mae: 0.0147 - mse: 3.5118e-04 - val_loss: 6.0300e-04 - val_mae: 0.0183 - val_mse: 6.0300e-04
# Epoch 40/100
# 180/180 [==============================] - ETA: 0s - loss: 3.5708e-04 - mae: 0.0149 - mse: 3.5708e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 3.5708e-04 - mae: 0.0149 - mse: 3.5708e-04 - val_loss: 4.6771e-04 - val_mae: 0.0154 - val_mse: 4.6771e-04
# Epoch 41/100
# 180/180 [==============================] - ETA: 0s - loss: 3.3961e-04 - mae: 0.0145 - mse: 3.3961e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 3.3961e-04 - mae: 0.0145 - mse: 3.3961e-04 - val_loss: 4.8829e-04 - val_mae: 0.0160 - val_mse: 4.8829e-04
# Epoch 42/100
# 180/180 [==============================] - ETA: 0s - loss: 3.3414e-04 - mae: 0.0144 - mse: 3.3414e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 3.3414e-04 - mae: 0.0144 - mse: 3.3414e-04 - val_loss: 4.8224e-04 - val_mae: 0.0156 - val_mse: 4.8224e-04
# Epoch 43/100
# 180/180 [==============================] - ETA: 0s - loss: 3.4704e-04 - mae: 0.0147 - mse: 3.4704e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 3.4704e-04 - mae: 0.0147 - mse: 3.4704e-04 - val_loss: 7.0998e-04 - val_mae: 0.0202 - val_mse: 7.0998e-04
# Epoch 44/100
# 180/180 [==============================] - ETA: 0s - loss: 3.3748e-04 - mae: 0.0144 - mse: 3.3748e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 3.3748e-04 - mae: 0.0144 - mse: 3.3748e-04 - val_loss: 5.0044e-04 - val_mae: 0.0158 - val_mse: 5.0044e-04
# Epoch 45/100
# 180/180 [==============================] - ETA: 0s - loss: 3.3394e-04 - mae: 0.0144 - mse: 3.3394e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 3.3394e-04 - mae: 0.0144 - mse: 3.3394e-04 - val_loss: 4.5521e-04 - val_mae: 0.0149 - val_mse: 4.5521e-04
# Epoch 46/100
# 180/180 [==============================] - ETA: 0s - loss: 3.3489e-04 - mae: 0.0144 - mse: 3.3489e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 3.3489e-04 - mae: 0.0144 - mse: 3.3489e-04 - val_loss: 4.8076e-04 - val_mae: 0.0153 - val_mse: 4.8076e-04
# Epoch 47/100
# 180/180 [==============================] - ETA: 0s - loss: 3.2249e-04 - mae: 0.0141 - mse: 3.2249e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 3.2249e-04 - mae: 0.0141 - mse: 3.2249e-04 - val_loss: 4.5450e-04 - val_mae: 0.0149 - val_mse: 4.5450e-04
# Epoch 48/100
# 180/180 [==============================] - ETA: 0s - loss: 3.2398e-04 - mae: 0.0141 - mse: 3.2398e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 3.2398e-04 - mae: 0.0141 - mse: 3.2398e-04 - val_loss: 5.3168e-04 - val_mae: 0.0177 - val_mse: 5.3168e-04
# Epoch 49/100
# 180/180 [==============================] - ETA: 0s - loss: 3.3005e-04 - mae: 0.0142 - mse: 3.3005e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 3.3005e-04 - mae: 0.0142 - mse: 3.3005e-04 - val_loss: 4.8443e-04 - val_mae: 0.0155 - val_mse: 4.8443e-04
# Epoch 50/100
# 180/180 [==============================] - ETA: 0s - loss: 3.0858e-04 - mae: 0.0137 - mse: 3.0858e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 3.0858e-04 - mae: 0.0137 - mse: 3.0858e-04 - val_loss: 4.6721e-04 - val_mae: 0.0155 - val_mse: 4.6721e-04
# Epoch 51/100
# 180/180 [==============================] - ETA: 0s - loss: 3.2888e-04 - mae: 0.0143 - mse: 3.2888e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 3.2888e-04 - mae: 0.0143 - mse: 3.2888e-04 - val_loss: 5.0863e-04 - val_mae: 0.0160 - val_mse: 5.0863e-04
# Epoch 52/100
# 180/180 [==============================] - ETA: 0s - loss: 3.0796e-04 - mae: 0.0138 - mse: 3.0796e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 3.0796e-04 - mae: 0.0138 - mse: 3.0796e-04 - val_loss: 4.6808e-04 - val_mae: 0.0150 - val_mse: 4.6808e-04
# Epoch 53/100
# 180/180 [==============================] - ETA: 0s - loss: 2.9957e-04 - mae: 0.0135 - mse: 2.9957e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 142ms/step - loss: 2.9957e-04 - mae: 0.0135 - mse: 2.9957e-04 - val_loss: 4.4124e-04 - val_mae: 0.0147 - val_mse: 4.4124e-04
# Epoch 54/100
# 180/180 [==============================] - ETA: 0s - loss: 2.9601e-04 - mae: 0.0134 - mse: 2.9601e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.9601e-04 - mae: 0.0134 - mse: 2.9601e-04 - val_loss: 4.9206e-04 - val_mae: 0.0165 - val_mse: 4.9206e-04
# Epoch 55/100
# 180/180 [==============================] - ETA: 0s - loss: 3.0856e-04 - mae: 0.0138 - mse: 3.0856e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 3.0856e-04 - mae: 0.0138 - mse: 3.0856e-04 - val_loss: 5.4206e-04 - val_mae: 0.0173 - val_mse: 5.4206e-04
# Epoch 56/100
# 180/180 [==============================] - ETA: 0s - loss: 2.9171e-04 - mae: 0.0134 - mse: 2.9171e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 142ms/step - loss: 2.9171e-04 - mae: 0.0134 - mse: 2.9171e-04 - val_loss: 5.2851e-04 - val_mae: 0.0167 - val_mse: 5.2851e-04
# Epoch 57/100
# 180/180 [==============================] - ETA: 0s - loss: 3.0556e-04 - mae: 0.0137 - mse: 3.0556e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 3.0556e-04 - mae: 0.0137 - mse: 3.0556e-04 - val_loss: 4.2967e-04 - val_mae: 0.0147 - val_mse: 4.2967e-04
# Epoch 58/100
# 180/180 [==============================] - ETA: 0s - loss: 2.7844e-04 - mae: 0.0130 - mse: 2.7844e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 143ms/step - loss: 2.7844e-04 - mae: 0.0130 - mse: 2.7844e-04 - val_loss: 5.8628e-04 - val_mae: 0.0178 - val_mse: 5.8628e-04
# Epoch 59/100
# 180/180 [==============================] - ETA: 0s - loss: 2.9216e-04 - mae: 0.0134 - mse: 2.9216e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.9216e-04 - mae: 0.0134 - mse: 2.9216e-04 - val_loss: 4.5367e-04 - val_mae: 0.0151 - val_mse: 4.5367e-04
# Epoch 60/100
# 180/180 [==============================] - ETA: 0s - loss: 2.8723e-04 - mae: 0.0133 - mse: 2.8723e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.8723e-04 - mae: 0.0133 - mse: 2.8723e-04 - val_loss: 4.6596e-04 - val_mae: 0.0155 - val_mse: 4.6596e-04
# Epoch 61/100
# 180/180 [==============================] - ETA: 0s - loss: 2.8485e-04 - mae: 0.0132 - mse: 2.8485e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.8485e-04 - mae: 0.0132 - mse: 2.8485e-04 - val_loss: 4.8233e-04 - val_mae: 0.0156 - val_mse: 4.8233e-04
# Epoch 62/100
# 180/180 [==============================] - ETA: 0s - loss: 2.7246e-04 - mae: 0.0129 - mse: 2.7246e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.7246e-04 - mae: 0.0129 - mse: 2.7246e-04 - val_loss: 4.7729e-04 - val_mae: 0.0156 - val_mse: 4.7729e-04
# Epoch 63/100
# 180/180 [==============================] - ETA: 0s - loss: 2.9062e-04 - mae: 0.0134 - mse: 2.9062e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 2.9062e-04 - mae: 0.0134 - mse: 2.9062e-04 - val_loss: 4.7474e-04 - val_mae: 0.0158 - val_mse: 4.7474e-04
# Epoch 64/100
# 180/180 [==============================] - ETA: 0s - loss: 2.7394e-04 - mae: 0.0129 - mse: 2.7394e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.7394e-04 - mae: 0.0129 - mse: 2.7394e-04 - val_loss: 4.6474e-04 - val_mae: 0.0157 - val_mse: 4.6474e-04
# Epoch 65/100
# 180/180 [==============================] - ETA: 0s - loss: 2.7126e-04 - mae: 0.0129 - mse: 2.7126e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 2.7126e-04 - mae: 0.0129 - mse: 2.7126e-04 - val_loss: 4.4037e-04 - val_mae: 0.0146 - val_mse: 4.4037e-04
# Epoch 66/100
# 180/180 [==============================] - ETA: 0s - loss: 2.8179e-04 - mae: 0.0131 - mse: 2.8179e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 139ms/step - loss: 2.8179e-04 - mae: 0.0131 - mse: 2.8179e-04 - val_loss: 4.7092e-04 - val_mae: 0.0159 - val_mse: 4.7092e-04
# Epoch 67/100
# 180/180 [==============================] - ETA: 0s - loss: 2.9270e-04 - mae: 0.0133 - mse: 2.9270e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 142ms/step - loss: 2.9270e-04 - mae: 0.0133 - mse: 2.9270e-04 - val_loss: 4.6562e-04 - val_mae: 0.0152 - val_mse: 4.6562e-04
# Epoch 68/100
# 180/180 [==============================] - ETA: 0s - loss: 2.7174e-04 - mae: 0.0129 - mse: 2.7174e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.7174e-04 - mae: 0.0129 - mse: 2.7174e-04 - val_loss: 4.8361e-04 - val_mae: 0.0159 - val_mse: 4.8361e-04
# Epoch 69/100
# 180/180 [==============================] - ETA: 0s - loss: 2.6092e-04 - mae: 0.0126 - mse: 2.6092e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.6092e-04 - mae: 0.0126 - mse: 2.6092e-04 - val_loss: 3.8841e-04 - val_mae: 0.0139 - val_mse: 3.8841e-04
# Epoch 70/100
# 180/180 [==============================] - ETA: 0s - loss: 2.7544e-04 - mae: 0.0130 - mse: 2.7544e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.7544e-04 - mae: 0.0130 - mse: 2.7544e-04 - val_loss: 4.7151e-04 - val_mae: 0.0157 - val_mse: 4.7151e-04
# Epoch 71/100
# 180/180 [==============================] - ETA: 0s - loss: 2.6080e-04 - mae: 0.0127 - mse: 2.6080e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.6080e-04 - mae: 0.0127 - mse: 2.6080e-04 - val_loss: 4.4393e-04 - val_mae: 0.0151 - val_mse: 4.4393e-04
# Epoch 72/100
# 180/180 [==============================] - ETA: 0s - loss: 2.6563e-04 - mae: 0.0127 - mse: 2.6563e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.6563e-04 - mae: 0.0127 - mse: 2.6563e-04 - val_loss: 4.7971e-04 - val_mae: 0.0161 - val_mse: 4.7971e-04
# Epoch 73/100
# 180/180 [==============================] - ETA: 0s - loss: 2.5869e-04 - mae: 0.0126 - mse: 2.5869e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.5869e-04 - mae: 0.0126 - mse: 2.5869e-04 - val_loss: 5.1195e-04 - val_mae: 0.0165 - val_mse: 5.1195e-04
# Epoch 74/100
# 180/180 [==============================] - ETA: 0s - loss: 2.6923e-04 - mae: 0.0128 - mse: 2.6923e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 143ms/step - loss: 2.6923e-04 - mae: 0.0128 - mse: 2.6923e-04 - val_loss: 4.3489e-04 - val_mae: 0.0154 - val_mse: 4.3489e-04
# Epoch 75/100
# 180/180 [==============================] - ETA: 0s - loss: 2.6157e-04 - mae: 0.0126 - mse: 2.6157e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 143ms/step - loss: 2.6157e-04 - mae: 0.0126 - mse: 2.6157e-04 - val_loss: 4.9772e-04 - val_mae: 0.0162 - val_mse: 4.9772e-04
# Epoch 76/100
# 180/180 [==============================] - ETA: 0s - loss: 2.5401e-04 - mae: 0.0124 - mse: 2.5401e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 26s 142ms/step - loss: 2.5401e-04 - mae: 0.0124 - mse: 2.5401e-04 - val_loss: 4.1894e-04 - val_mae: 0.0146 - val_mse: 4.1894e-04
# Epoch 77/100
# 180/180 [==============================] - ETA: 0s - loss: 2.5559e-04 - mae: 0.0125 - mse: 2.5559e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.5559e-04 - mae: 0.0125 - mse: 2.5559e-04 - val_loss: 4.2220e-04 - val_mae: 0.0144 - val_mse: 4.2220e-04
# Epoch 78/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4516e-04 - mae: 0.0122 - mse: 2.4516e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.4516e-04 - mae: 0.0122 - mse: 2.4516e-04 - val_loss: 4.0943e-04 - val_mae: 0.0144 - val_mse: 4.0943e-04
# Epoch 79/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4721e-04 - mae: 0.0123 - mse: 2.4721e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.4721e-04 - mae: 0.0123 - mse: 2.4721e-04 - val_loss: 4.6972e-04 - val_mae: 0.0156 - val_mse: 4.6972e-04
# Epoch 80/100
# 180/180 [==============================] - ETA: 0s - loss: 2.5104e-04 - mae: 0.0124 - mse: 2.5104e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.5104e-04 - mae: 0.0124 - mse: 2.5104e-04 - val_loss: 5.3713e-04 - val_mae: 0.0178 - val_mse: 5.3713e-04
# Epoch 81/100
# 180/180 [==============================] - ETA: 0s - loss: 2.5409e-04 - mae: 0.0124 - mse: 2.5409e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.5409e-04 - mae: 0.0124 - mse: 2.5409e-04 - val_loss: 4.8198e-04 - val_mae: 0.0161 - val_mse: 4.8198e-04
# Epoch 82/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4963e-04 - mae: 0.0123 - mse: 2.4963e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.4963e-04 - mae: 0.0123 - mse: 2.4963e-04 - val_loss: 3.7410e-04 - val_mae: 0.0135 - val_mse: 3.7410e-04
# Epoch 83/100
# 180/180 [==============================] - ETA: 0s - loss: 2.5316e-04 - mae: 0.0125 - mse: 2.5316e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.5316e-04 - mae: 0.0125 - mse: 2.5316e-04 - val_loss: 3.8871e-04 - val_mae: 0.0137 - val_mse: 3.8871e-04
# Epoch 84/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4388e-04 - mae: 0.0122 - mse: 2.4388e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.4388e-04 - mae: 0.0122 - mse: 2.4388e-04 - val_loss: 3.9708e-04 - val_mae: 0.0141 - val_mse: 3.9708e-04
# Epoch 85/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4661e-04 - mae: 0.0123 - mse: 2.4661e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.4661e-04 - mae: 0.0123 - mse: 2.4661e-04 - val_loss: 4.1058e-04 - val_mae: 0.0143 - val_mse: 4.1058e-04
# Epoch 86/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4782e-04 - mae: 0.0123 - mse: 2.4782e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 141ms/step - loss: 2.4782e-04 - mae: 0.0123 - mse: 2.4782e-04 - val_loss: 4.1244e-04 - val_mae: 0.0143 - val_mse: 4.1244e-04
# Epoch 87/100
# 180/180 [==============================] - ETA: 0s - loss: 2.5348e-04 - mae: 0.0124 - mse: 2.5348e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 138ms/step - loss: 2.5348e-04 - mae: 0.0124 - mse: 2.5348e-04 - val_loss: 3.9990e-04 - val_mae: 0.0144 - val_mse: 3.9990e-04
# Epoch 88/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4698e-04 - mae: 0.0123 - mse: 2.4698e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.4698e-04 - mae: 0.0123 - mse: 2.4698e-04 - val_loss: 5.0373e-04 - val_mae: 0.0165 - val_mse: 5.0373e-04
# Epoch 89/100
# 180/180 [==============================] - ETA: 0s - loss: 2.4813e-04 - mae: 0.0123 - mse: 2.4813e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 25s 140ms/step - loss: 2.4813e-04 - mae: 0.0123 - mse: 2.4813e-04 - val_loss: 5.7543e-04 - val_mae: 0.0185 - val_mse: 5.7543e-04
# Epoch 90/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.4345e-04 - mae: 0.0122 - mse: 2.4345e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 20s 109ms/step - loss: 2.4338e-04 - mae: 0.0122 - mse: 2.4338e-04 - val_loss: 4.2176e-04 - val_mae: 0.0147 - val_mse: 4.2176e-04
# Epoch 91/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.4467e-04 - mae: 0.0122 - mse: 2.4467e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 102ms/step - loss: 2.4452e-04 - mae: 0.0122 - mse: 2.4452e-04 - val_loss: 4.8906e-04 - val_mae: 0.0169 - val_mse: 4.8906e-04
# Epoch 92/100
# 180/180 [==============================] - ETA: 0s - loss: 2.3358e-04 - mae: 0.0120 - mse: 2.3358e-04- ETA: 3s - loss: 2.3543eWARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 19s 103ms/step - loss: 2.3358e-04 - mae: 0.0120 - mse: 2.3358e-04 - val_loss: 4.3335e-04 - val_mae: 0.0150 - val_mse: 4.3335e-04
# Epoch 93/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.3012e-04 - mae: 0.0119 - mse: 2.3012e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 102ms/step - loss: 2.2994e-04 - mae: 0.0119 - mse: 2.2994e-04 - val_loss: 3.8063e-04 - val_mae: 0.0142 - val_mse: 3.8063e-04
# Epoch 94/100
# 180/180 [==============================] - ETA: 0s - loss: 2.2649e-04 - mae: 0.0119 - mse: 2.2649e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 19s 103ms/step - loss: 2.2649e-04 - mae: 0.0119 - mse: 2.2649e-04 - val_loss: 4.4783e-04 - val_mae: 0.0152 - val_mse: 4.4783e-04
# Epoch 95/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.2355e-04 - mae: 0.0117 - mse: 2.2355e-04- ETA: 1s - loss: 2.1845e-04 - mae: 0.0115 - msWARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 101ms/step - loss: 2.2384e-04 - mae: 0.0117 - mse: 2.2384e-04 - val_loss: 6.0371e-04 - val_mae: 0.0195 - val_mse: 6.0371e-04
# Epoch 96/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.2753e-04 - mae: 0.0118 - mse: 2.2753e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 101ms/step - loss: 2.2761e-04 - mae: 0.0118 - mse: 2.2761e-04 - val_loss: 4.0740e-04 - val_mae: 0.0144 - val_mse: 4.0740e-04
# Epoch 97/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.2818e-04 - mae: 0.0118 - mse: 2.2818e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 102ms/step - loss: 2.2813e-04 - mae: 0.0118 - mse: 2.2813e-04 - val_loss: 3.7989e-04 - val_mae: 0.0140 - val_mse: 3.7989e-04
# Epoch 98/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.2848e-04 - mae: 0.0118 - mse: 2.2848e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 103ms/step - loss: 2.2836e-04 - mae: 0.0118 - mse: 2.2836e-04 - val_loss: 3.9283e-04 - val_mae: 0.0144 - val_mse: 3.9283e-04
# Epoch 99/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.3330e-04 - mae: 0.0120 - mse: 2.3330e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 103ms/step - loss: 2.3344e-04 - mae: 0.0120 - mse: 2.3344e-04 - val_loss: 4.3136e-04 - val_mae: 0.0154 - val_mse: 4.3136e-04
# Epoch 100/100
# 179/180 [============================>.] - ETA: 0s - loss: 2.3697e-04 - mae: 0.0120 - mse: 2.3697e-04WARNING:tensorflow:Can save best model only with val_mean_squared_error available, skipping.
# 180/180 [==============================] - 18s 103ms/step - loss: 2.3679e-04 - mae: 0.0120 - mse: 2.3679e-04 - val_loss: 4.6735e-04 - val_mae: 0.0160 - val_mse: 4.6735e-04

# %%
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('Mean Squared Error of SIE Prediction')
plt.ylabel('MSE')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Mean Absolute Error of SIE Prediction')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss of SIE Prediction')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from numpy import sqrt

#model.load_weights("weights.best.hdf5")

pred = model.predict(testX)

predicted_dataset = dataset
predicted_dataset[len(predicted_dataset)-len(pred):, 12] = pred[:, 0]
scaled_predicted_dataset = scaler.inverse_transform(predicted_dataset)

predicted_df = df.copy()
predicted_df['sea_ice_extent'][len(predicted_dataset)-len(pred):] = scaled_predicted_dataset[len(predicted_dataset)-len(pred):, 12]

predictions = pd.DataFrame()
predictions['predicted'] = (predicted_df['sea_ice_extent'][len(predicted_dataset)-len(pred):])
predictions['actual'] = (df['sea_ice_extent'][len(predicted_dataset)-len(pred):])
predictions = predictions.astype(float)
# Out:
# C:\Users\FAHAD\AppData\Local\Temp/ipykernel_35268/1920052413.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predicted_df['sea_ice_extent'][len(predicted_dataset)-len(pred):] = scaled_predicted_dataset[len(predicted_dataset)-len(pred):, 12]

# %%
print(len(predictions['actual']))
# Out:
# 1826

# %%
plt.figure(figsize = (16,6), facecolor = '#dcdcdc')
ax = plt.axes()
ax.set_facecolor('#dcdcdc')

plt.title('Arctic Sea Ice Extent Actual vs Prediction Curve for Test Data', fontsize = 20,fontweight = "bold")
plt.xlabel('Time' , fontsize = 18,fontweight = "bold")
plt.ylabel('Sea Ice Extent (10\u2076 km\u00b2)', fontsize = 18,fontweight = "bold")
plt.plot(predictions['actual'], 'blue', label='Actual SIE')
plt.plot(predictions['predicted'], 'red', label='Predicted SIE')
plt.legend()
plt.grid()
plt.show

predictions['diff'] = predictions['predicted'] - predictions['actual']
plt.figure(figsize=(10,10))
plt.xlabel('Difference between actual and predicted SIE (10\u2076 km\u00b2)')
sns.histplot(predictions['diff'])
plt.title('Distribution of differences between actual and predicted SIE')
plt.show()

mspe = (np.mean(np.square((predictions['actual'].values - predictions['predicted'].values) / predictions['actual'].values))) * 100
rmspe = (np.sqrt(np.mean(np.square((predictions['actual'].values - predictions['predicted'].values) / predictions['actual'].values)))) * 100

print("MSE : ", mean_squared_error(predictions['predicted'].values, predictions['actual'].values), "(10\u2076 km\u00b2)")
print("MSPE :", mspe, "%")
print("RMSE : ", sqrt(mean_squared_error(predictions['predicted'].values, predictions['actual'].values)), "(10\u2076 km\u00b2)")
print("RMSPE :", rmspe, "%")
print("MAE : ", mean_absolute_error(predictions['predicted'].values, predictions['actual'].values), "(10\u2076 km\u00b2)")
print("MAPE : ", mean_absolute_percentage_error(predictions['predicted'].values, predictions['actual'].values)*100, "%")
print("R2 : ", r2_score(predictions['predicted'].values, predictions['actual'].values))
# Out:
# MSE :  0.06769378003983573 (10⁶ km²)
# MSPE : 0.10554312450723254 %
# RMSE :  0.2601802837261804 (10⁶ km²)
# RMSPE : 3.2487401328396914 %
# MAE :  0.21145438804342348 (10⁶ km²)
# MAPE :  2.3807062642740484 %
# R2 :  0.9944123956221109
